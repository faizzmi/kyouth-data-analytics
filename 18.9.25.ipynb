# %%
#OPERATION 1 CLEANING THE CUSTOMER RETAIL DATA
#NOTE: THE ONE WE GONNA PREDICT IS THE DEPENDANT FEATURES

import pandas as pd

#Load the dataset
df = pd.read_csv("customer_retail.csv")

#Display the first 5 rows
display(df.head())

#Check the shape of dataset
print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.")

#Display column names and data types
print("\nColumn Names and Data Types:")
print(df.dtypes)

# Get summary statistics
print("\nSummary Statistics:")
display(df.describe())

df.info()

#CHECK FOR MISSING VALUES
print("\nMissing Values Count:\n", df.isnull().sum())

#DISPLAY ROWS WITH MISSING VALUES
display(df[df.isnull().any(axis=1)])

# - List all type of categorial data exist in data
print(customers['education'].unique())

# Show rows where 'education' is missing (before imputation)

education_missing_before = customers[customers['education'].isnull()]
print(education_missing_before[['age', 'education']])

# First, create a copy of the original column before imputation
customers['education_original'] = customers['education']

# Perform imputation
def infer_education(age):
    if pd.isnull(age):
        return np.nan
    elif age < 22:
        return 'College'
    elif 22 <= age < 30:
        return 'Bachelor'
    elif 30 <= age <= 40:
        return 'Masters'
    else:
        return 'Bachelor'

# Fill missing values
customers['education'] = customers['education'].fillna(customers['age'].apply(infer_education))

# Show only rows where imputation occurred
imputed_rows = customers[customers['education_original'].isnull()]
print(imputed_rows[['age', 'education']])

#REMOVE ROWS WHERE "satisfaction_score" AND "purchase_frequency" IS MISSING
df_cleaned1 = df.dropna(subset=['satisfaction_score', 'purchase_frequency'])

#DISPLAY THE NUMBER OF REMAINING MISSING VALUES TO VERIFY
print("\nMissing values after cleaning:\n")
print(df_cleaned1.isnull().sum())

# Show rows where 'education' is missing (before imputation)
education_missing_before = customers[customers['education'].isnull()]
print(education_missing_before[['age', 'education']])

#CHECK FOR THE DUPLICATES
duplicates = df_cleaned1.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}\n")

#DISPLAY DUPLICATE ROWS IF ANY EXIST
if duplicates > 0:
    print("Duplicate rows found:")
    display(df_cleaned1[df_cleaned1.duplicated(keep=False)])

#DEFINE THE FILE PATH FOR SAVING
output_file = "cleaned_customer_retail.csv"

#EXPORT THE CLEANED DATASET
df_cleaned1.to_csv(output_file, index=False)

print(f"Cleaned dataset has been successfully saved as:{output_file}")
# Out:
#    id  age  gender  income   education region loyalty_status  \
# 0   1   27    Male   40682    Bachelor   East           Gold
# 1   2   29    Male   15317     Masters   West        Regular
# 2   3   37    Male   38849    Bachelor   West         Silver
# 3   4   30    Male   11568  HighSchool  South        Regular
# 4   5   31  Female   46952     College  North        Regular
#
#   purchase_frequency  purchase_amount product_category  promotion_usage  \
# 0           frequent            18249            Books                0
# 1               rare             4557         Clothing                1
# 2               rare            11822         Clothing                0
# 3           frequent             4098             Food                0
# 4         occasional            19685         Clothing                1
#
#    satisfaction_score
# 0                 6.0
# 1                 6.0
# 2                 6.0
# 3                 7.0
# 4                 5.0
# ...
